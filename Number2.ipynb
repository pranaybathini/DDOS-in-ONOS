# %%
import pandas as pd
import numpy as np

# %%
dftrain = pd.read_csv("round1_ijcai_18_train_20180301.csv",sep = ' ')

# %%
dftest = pd.read_csv("round1_ijcai_18_test_a_20180301.txt", sep = ' ')

# %%
dftrain.head()
dftrain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478138 entries, 0 to 478137
# Data columns (total 27 columns):
# instance_id                  478138 non-null int64
# item_id                      478138 non-null int64
# item_category_list           478138 non-null object
# item_property_list           478138 non-null object
# item_brand_id                478138 non-null int64
# item_city_id                 478138 non-null int64
# item_price_level             478138 non-null int64
# item_sales_level             478138 non-null int64
# item_collected_level         478138 non-null int64
# item_pv_level                478138 non-null int64
# user_id                      478138 non-null int64
# user_gender_id               478138 non-null int64
# user_age_level               478138 non-null int64
# user_occupation_id           478138 non-null int64
# user_star_level              478138 non-null int64
# context_id                   478138 non-null int64
# ...

# %%
dftest.head()
# Out:
#            instance_id              item_id  \
# 0  2475218615076601065  2275895163219263378
# 1   398316874173557226  7096238490711246967
# 2  6586402638209028583  7096238490711246967
# 3  1040996105851528465  7096238490711246967
# 4  6316278569655873454  7096238490711246967
#
#                         item_category_list  \
# 0  7908382889764677758;8277336076276184272
# 1  7908382889764677758;5755694407684602296
# 2  7908382889764677758;5755694407684602296
# 3  7908382889764677758;5755694407684602296
# 4  7908382889764677758;5755694407684602296
#
#                                   item_property_list        item_brand_id  \
# 0  2636395404473730413;7515802706813700848;302719...  7838285046767229711
# 1  5131280576272319091;2636395404473730413;734498...  8126195666233054089
# 2  5131280576272319091;2636395404473730413;734498...  8126195666233054089
# 3  5131280576272319091;2636395404473730413;734498...  8126195666233054089
# ...

# %%
clickedSample = dftrain[['instance_id','is_trade','item_id','user_id','context_id','shop_id']]

# %%
clickedSample.head()
# Out:
#            instance_id  is_trade              item_id              user_id  \
# 0   108641074714126964         0  3412720377098676069  4505772604969228686
# 1  5754713551599725161         0  3412720377098676069  2692638157208937547
# 2   842679481291040981         0  3412720377098676069  5247924392014515924
# 3   937088850059189027         0  3412720377098676069  2681414445369714628
# 4  7975697065017708072         0  3412720377098676069  2729475788342039013
#
#             context_id              shop_id
# 0   282924576738839389  6765930309048922341
# 1  4007979028023783431  6765930309048922341
# 2  4884875192608989870  6765930309048922341
# 3   840119421106178602  6765930309048922341
# 4  1736769971710354684  6765930309048922341

# %%
clickedSample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478138 entries, 0 to 478137
# Data columns (total 6 columns):
# instance_id    478138 non-null int64
# is_trade       478138 non-null int64
# item_id        478138 non-null int64
# user_id        478138 non-null int64
# context_id     478138 non-null int64
# shop_id        478138 non-null int64
# dtypes: int64(6)
# memory usage: 21.9 MB

# %%
# Out:
# 5479907258807096112    3
# 3370133319712542740    3
# 2535273059737073357    2
# 4984307821968110563    2
# 6031880284089240838    2
# 251764820957840061     2
# 2820033257616039272    2
# 833314485724646554     2
# 3779422444610157507    2
# 2247966536605008332    2
# 4716737653711059052    2
# 5547571229532052578    2
# 8495813758894672234    2
# 683023144061510567     2
# 5734962558666346526    2
# 8042010293411636231    2
# 6214707899917303043    2
# 6678029068572439929    2
# 644690756602987584     2
# 6020113693432894079    2
# 7773970221732336968    2
# 4713809052247380232    2
# 191012710137081307     2
# 6484429841255256717    2
# 6524018179115275803    2
# 1037061371711078396    2
# 7983370106370683357    2
# 7448305858307931414    2
# 7997153237845815308    2
# 6344363116315363445    2
#                       ..
# 1204011044917236229    1
# 7234190422928073251    1
# 569893601106372361     1
# 7686108008974358413    1
# 2133180959478018283    1
# 3059489617484100694    1
# ...

# %%
clickedSamples = clickedSample.drop_duplicates()

# %%
clickedSamples.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 478111 entries, 0 to 478137
# Data columns (total 6 columns):
# instance_id    478111 non-null int64
# is_trade       478111 non-null int64
# item_id        478111 non-null int64
# user_id        478111 non-null int64
# context_id     478111 non-null int64
# shop_id        478111 non-null int64
# dtypes: int64(6)
# memory usage: 25.5 MB

# %%
clickedSamples.instance_id.value_counts()
# Out:
# 2535273059737073357    2
# 6344363116315363445    2
# 1037061371711078396    2
# 2264716673495444735    2
# 6592583059060882788    2
# 348545486282294646     2
# 2910529267144588090    2
# 191012710137081307     2
# 644690756602987584     2
# 4110443799016068208    2
# 7773970221732336968    2
# 4598693726484786606    2
# 8042010293411636231    2
# 6214707899917303043    2
# 8495813758894672234    2
# 4716737653711059052    2
# 6484429841255256717    2
# 6020113693432894079    2
# 6458098125008270690    2
# 251764820957840061     2
# 4505908068775890459    2
# 2820033257616039272    2
# 6031880284089240838    2
# 7613854672358296887    2
# 7976791347830683894    1
# 5291051777058952190    1
# 4786333317945974262    1
# 7624289353549415715    1
# 1254516543081130071    1
# 1277204676569062031    1
#                       ..
# 4757241322529199156    1
# 2308215517964350519    1
# 4500579299644989471    1
# 9037510016191738257    1
# 722076614882461939     1
# 7640697350130511938    1
# ...

# %%
seri = clickedSamples.instance_id.value_counts()

# %%
seri = seri.loc[2535273059737073357:7613854672358296887]

# %%
seri.shape
# Out:
# (24,)

# %%
serie = pd.DataFrame(seri)

# %%
serie
# Out:
#                      instance_id
# 2535273059737073357            2
# 6344363116315363445            2
# 1037061371711078396            2
# 2264716673495444735            2
# 6592583059060882788            2
# 348545486282294646             2
# 2910529267144588090            2
# 191012710137081307             2
# 644690756602987584             2
# 4110443799016068208            2
# 7773970221732336968            2
# 4598693726484786606            2
# 8042010293411636231            2
# 6214707899917303043            2
# 8495813758894672234            2
# 4716737653711059052            2
# 6484429841255256717            2
# 6020113693432894079            2
# 6458098125008270690            2
# 251764820957840061             2
# 4505908068775890459            2
# 2820033257616039272            2
# 6031880284089240838            2
# 7613854672358296887            2

# %%
dftrain.loc[dftrain['instance_id'].isin(serie.index)]
# Out:
#                 instance_id              item_id  \
# 52983   2910529267144588090  7662858537138663632
# 59143   8042010293411636231  8525591893359299069
# 69717   4110443799016068208  7336200803790537549
# 88934    251764820957840061  1641974005505706555
# 95666   4110443799016068208  5002281858712787472
# 102069  7613854672358296887  3929415616875746448
# 108935   348545486282294646  3283029658215624826
# 115670  4598693726484786606  9164425217944793527
# 117820  4505908068775890459   452806982292021518
# 123957   644690756602987584  3275099097645146109
# 129013   348545486282294646  5322956081233923609
# 134257  6031880284089240838  1121649958974113109
# 135963  6458098125008270690  4015241264542116960
# 154545  6592583059060882788  7937690818610877888
# 179552  6344363116315363445  5784172846770221439
# 180736  2535273059737073357  1855114698389706052
# 185378  4598693726484786606  5732254680466261511
# 187350  6020113693432894079   128341368581443970
# ...

# %%
clickedSamples.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 478111 entries, 0 to 478137
# Data columns (total 6 columns):
# instance_id    478111 non-null int64
# is_trade       478111 non-null int64
# item_id        478111 non-null int64
# user_id        478111 non-null int64
# context_id     478111 non-null int64
# shop_id        478111 non-null int64
# dtypes: int64(6)
# memory usage: 25.5 MB

# %%
clickedSamples.to_csv("Final/clickedSamples.csv", encoding='utf-8', index=False)

# %%
item = dftrain[['item_id', 'item_brand_id', 'item_city_id', 'item_price_level', 'item_sales_level', 'item_collected_level', 'item_pv_level']]

# %%
item.head()
# Out:
#                item_id        item_brand_id         item_city_id  \
# 0  3412720377098676069  1975590437749032870  3948283326616421003
# 1  3412720377098676069  1975590437749032870  3948283326616421003
# 2  3412720377098676069  1975590437749032870  3948283326616421003
# 3  3412720377098676069  1975590437749032870  3948283326616421003
# 4  3412720377098676069  1975590437749032870  3948283326616421003
#
#    item_price_level  item_sales_level  item_collected_level  item_pv_level
# 0                 3                 3                     4             14
# 1                 3                 3                     4             14
# 2                 3                 3                     4             14
# 3                 3                 3                     4             14
# 4                 3                 3                     4             14

# %%
item.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478138 entries, 0 to 478137
# Data columns (total 7 columns):
# item_id                 478138 non-null int64
# item_brand_id           478138 non-null int64
# item_city_id            478138 non-null int64
# item_price_level        478138 non-null int64
# item_sales_level        478138 non-null int64
# item_collected_level    478138 non-null int64
# item_pv_level           478138 non-null int64
# dtypes: int64(7)
# memory usage: 25.5 MB

# %%
items = item.drop_duplicates()

# %%
items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16293 entries, 0 to 478119
# Data columns (total 7 columns):
# item_id                 16293 non-null int64
# item_brand_id           16293 non-null int64
# item_city_id            16293 non-null int64
# item_price_level        16293 non-null int64
# item_sales_level        16293 non-null int64
# item_collected_level    16293 non-null int64
# item_pv_level           16293 non-null int64
# dtypes: int64(7)
# memory usage: 1018.3 KB

# %%
item1 = dftrain[['item_id', 'item_brand_id', 'item_city_id', 'item_price_level', 'item_sales_level', 'item_collected_level', 'item_pv_level','item_category_list', 'item_property_list']]

# %%
item1s = item1.drop_duplicates()

# %%
item1s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16928 entries, 0 to 478119
# Data columns (total 9 columns):
# item_id                 16928 non-null int64
# item_brand_id           16928 non-null int64
# item_city_id            16928 non-null int64
# item_price_level        16928 non-null int64
# item_sales_level        16928 non-null int64
# item_collected_level    16928 non-null int64
# item_pv_level           16928 non-null int64
# item_category_list      16928 non-null object
# item_property_list      16928 non-null object
# dtypes: int64(7), object(2)
# memory usage: 1.3+ MB

# %%
item1s = item1s.sort_values("item_id", axis = 0)

# %%
item1s.to_csv("items.csv", encoding='utf-8', index=False)

# %%
item1s.item_id.value_counts()
# Out:
# 7622084632159279307    7
# 913612958433505538     7
# 3971884819315952278    7
# 875803320700057363     7
# 5986206313096027293    7
# 7897966471792248924    7
# 8972459948167865782    7
# 6119874605501071236    6
# 7789379599511448576    6
# 5146618483637444020    6
# 9122301541885629117    6
# 6551271232714998121    6
# 5347686743547805090    6
# 5061447490697488178    6
# 4829783980320085769    6
# 6177455112506461446    6
# 8569396460587831427    6
# 8571444008629948811    6
# 5601741729441083168    6
# 3307847616289270161    6
# 8224451481048956467    6
# 509936336103770855     6
# 8280752807027804716    6
# 5809767789301533998    6
# 8906948455106358440    6
# 3867772824623167731    6
# 1466207274589169492    6
# 493576211118522692     6
# 51600763759942867      6
# 6331606763113247801    6
#                       ..
# 9038369089515220767    1
# 1683343717137076580    1
# 6565134234111151208    1
# 7719924666422464066    1
# 5572328077590128746    1
# 3700388478703774938    1
# ...

# %%
item1s.duplicated("item_id", False)
# Out:
# 271475     True
# 124006     True
# 67656      True
# 15695      True
# 89009      True
# 346984     True
# 66321      True
# 119478    False
# 443921    False
# 124272    False
# 442130    False
# 255204    False
# 54386     False
# 128132     True
# 337588     True
# 275202     True
# 38370      True
# 327399     True
# 123167     True
# 30477     False
# 67429     False
# 53887     False
# 69881      True
# 419144     True
# 136078    False
# 71005     False
# 316125    False
# 456918    False
# 138007     True
# 365400     True
#           ...
# 301168     True
# 95136      True
# 51771     False
# 69075     False
# 355484     True
# 146565     True
# 74190      True
# 54274     False
# 67881     False
# 74049     False
# 53884      True
# 190118     True
# 434754     True
# 367924     True
# 94700      True
# 12673      True
# 45932     False
# 137805     True
# 67537      True
# 124395     True
# 46881      True
# 365819    False
# 76669      True
# 288047     True
# ...

# %%
item1s.item_id.value_counts()
# Out:
# 3971884819315952278    7
# 8972459948167865782    7
# 7622084632159279307    7
# 5986206313096027293    7
# 7897966471792248924    7
# 913612958433505538     7
# 875803320700057363     7
# 1846308293355898764    6
# 9136469604860285707    6
# 3307847616289270161    6
# 1507948276097578293    6
# 5061447490697488178    6
# 7789379599511448576    6
# 6177455112506461446    6
# 5347686743547805090    6
# 7999373343786573571    6
# 493576211118522692     6
# 8571444008629948811    6
# 6119874605501071236    6
# 5809767789301533998    6
# 8280752807027804716    6
# 8569396460587831427    6
# 3867772824623167731    6
# 4829783980320085769    6
# 51600763759942867      6
# 5601741729441083168    6
# 1743425797982082550    6
# 1466207274589169492    6
# 8224451481048956467    6
# 6331606763113247801    6
#                       ..
# 4927803669253941493    1
# 7448847877393856182    1
# 426513857620884421     1
# 8203061769296177222    1
# 6421041613072713584    1
# 7461008835316617942    1
# ...

# %%
item2 = dftrain[['item_id', 'item_brand_id']]

# %% [markdown]
# item2s = item2.drop_duplicates()

# %%
item2s = item2.drop_duplicates()
item2s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10091 entries, 0 to 478119
# Data columns (total 2 columns):
# item_id          10091 non-null int64
# item_brand_id    10091 non-null int64
# dtypes: int64(2)
# memory usage: 236.5 KB

# %%
ids = item1s["item_id"]
yoyo = item1s[ids.isin(ids[ids.duplicated()])].sort_values("item_id")
yoyo.to_csv("items.csv", encoding='utf-8', index=False)

# %%
yoyo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11511 entries, 271475 to 393913
# Data columns (total 9 columns):
# item_id                 11511 non-null int64
# item_brand_id           11511 non-null int64
# item_city_id            11511 non-null int64
# item_price_level        11511 non-null int64
# item_sales_level        11511 non-null int64
# item_collected_level    11511 non-null int64
# item_pv_level           11511 non-null int64
# item_category_list      11511 non-null object
# item_property_list      11511 non-null object
# dtypes: int64(7), object(2)
# memory usage: 899.3+ KB

# %%
ypo = dftrain[["item_id", 'item_brand_id']]
ypo = ypo.drop_duplicates()
ids = ypo["item_id"]
ypo = ypo[ids.isin(ids[ids.duplicated()])].sort_values("item_id")
ypo.to_csv("items.csv", encoding='utf-8', index=False)

# %%
dftrain["context_timestamp"].value_counts()
# Out:
# 1537704211    12
# 1537625383    11
# 1537535936    11
# 1537356990    10
# 1537494187    10
# 1537246073    10
# 1537712124    10
# 1537624982     9
# 1537278144     9
# 1537700659     9
# 1537449178     9
# 1537276109     9
# 1537277164     9
# 1537418462     9
# 1537362372     9
# 1537711270     9
# 1537618518     9
# 1537519970     9
# 1537452858     9
# 1537364105     9
# 1537279076     9
# 1537796769     9
# 1537539926     9
# 1537627369     9
# 1537513155     9
# 1537582796     8
# 1537271675     8
# 1537452170     8
# 1537268878     8
# 1537714682     8
#               ..
# 1537526283     1
# 1537524234     1
# 1537516038     1
# 1537436159     1
# 1537427963     1
# 1537610320     1
# 1537612369     1
# 1537614422     1
# 1537274508     1
# 1537317537     1
# 1537315488     1
# 1537766044     1
# 1537235609     1
# 1537747607     1
# 1537227413     1
# 1537225364     1
# 1537272463     1
# 1537276557     1
# 1537268361     1
# 1537773217     1
# 1537247875     1
# ...

# %%
dftrain["context_timestamp"].sort_values()
# Out:
# 3844      1537200001
# 24046     1537200004
# 59329     1537200005
# 70767     1537200011
# 76650     1537200014
# 27196     1537200014
# 59196     1537200016
# 57458     1537200016
# 23301     1537200017
# 24479     1537200017
# 3700      1537200017
# 27205     1537200017
# 23424     1537200020
# 55722     1537200023
# 75549     1537200024
# 61130     1537200025
# 6978      1537200027
# 70761     1537200027
# 52903     1537200028
# 48241     1537200031
# 37121     1537200031
# 60908     1537200032
# 61        1537200034
# 63922     1537200034
# 70058     1537200035
# 25034     1537200035
# 7353      1537200037
# 29069     1537200038
# 16226     1537200039
# 37086     1537200040
#              ...
# 456662    1537804711
# 431076    1537804712
# 468469    1537804712
# 463768    1537804712
# 430122    1537804716
# 446433    1537804719
# 448545    1537804725
# 472059    1537804727
# 459943    1537804734
# 446362    1537804736
# 452400    1537804739
# 467799    1537804740
# ...

# %%
dftest["context_timestamp"].sort_values()
# Out:
# 6594     1537804802
# 2782     1537804820
# 9049     1537804825
# 13921    1537804829
# 6324     1537804831
# 12064    1537804831
# 3087     1537804836
# 5986     1537804838
# 2237     1537804839
# 435      1537804843
# 12708    1537804856
# 18159    1537804858
# 14382    1537804861
# 15298    1537804872
# 3396     1537804873
# 6841     1537804874
# 3994     1537804912
# 14359    1537804914
# 16540    1537804930
# 12777    1537804943
# 614      1537804950
# 8001     1537804952
# 7739     1537804997
# 11678    1537804998
# 13854    1537805011
# 14360    1537805012
# 17695    1537805019
# 1433     1537805023
# 10916    1537805035
# 16099    1537805053
#             ...
# 16524    1537890967
# 9473     1537890972
# 17140    1537890974
# 297      1537890979
# 14454    1537890979
# 12214    1537890982
# 6037     1537890982
# 9179     1537890983
# 4214     1537890987
# 4331     1537890997
# 13503    1537891001
# 15772    1537891015
# 12108    1537891023
# 6874     1537891023
# ...

# %%
helli = dftrain["item_category_list"].value_counts()

# %%
helli.index
# Out:
# Index(['7908382889764677758;8277336076276184272',
#        '7908382889764677758;5755694407684602296',
#        '7908382889764677758;509660095530134768',
#        '7908382889764677758;5799347067982556520',
#        '7908382889764677758;7258015885215914736',
#        '7908382889764677758;2011981573061447208',
#        '7908382889764677758;8710739180200009128',
#        '7908382889764677758;3203673979138763595',
#        '7908382889764677758;2436715285093487584',
#        '7908382889764677758;2642175453151805566;8868887661186419229',
#        '7908382889764677758;4879721024980945592',
#        '7908382889764677758;1968056100269760729',
#        '7908382889764677758;2642175453151805566;6233669177166538628',
#        '7908382889764677758;22731265849056483'],
#       dtype='object')

# %%
dftest["item_category_list"].value_counts()
# Out:
# 7908382889764677758;8277336076276184272                        6098
# 7908382889764677758;5755694407684602296                        4033
# 7908382889764677758;509660095530134768                         2932
# 7908382889764677758;5799347067982556520                        2726
# 7908382889764677758;7258015885215914736                        1464
# 7908382889764677758;2011981573061447208                         373
# 7908382889764677758;8710739180200009128                         304
# 7908382889764677758;3203673979138763595                         223
# 7908382889764677758;2642175453151805566;8868887661186419229      75
# 7908382889764677758;2436715285093487584                          72
# 7908382889764677758;4879721024980945592                          55
# 7908382889764677758;1968056100269760729                          10
# 7908382889764677758;2642175453151805566;6233669177166538628       4
# 7908382889764677758;22731265849056483                             2
# ...

# %%
dftrain["item_category_list"].value_counts()
# Out:
# 7908382889764677758;8277336076276184272                        150779
# 7908382889764677758;5755694407684602296                        102496
# 7908382889764677758;509660095530134768                          75420
# 7908382889764677758;5799347067982556520                         72019
# 7908382889764677758;7258015885215914736                         53055
# 7908382889764677758;2011981573061447208                          9563
# 7908382889764677758;8710739180200009128                          7084
# 7908382889764677758;3203673979138763595                          2246
# 7908382889764677758;2436715285093487584                          1966
# 7908382889764677758;2642175453151805566;8868887661186419229      1906
# 7908382889764677758;4879721024980945592                          1207
# 7908382889764677758;1968056100269760729                           186
# 7908382889764677758;2642175453151805566;6233669177166538628       123
# ...

# %%
y = helli.index
z = []
xz = []
for i in y:
    x = dftrain.loc[dftrain['item_category_list'] == i]
    z.append(x["is_trade"].value_counts())

# %%
z = pd.DataFrame(z)

# %%
z
# Out:
#                0     1
# is_trade  148830  1949
# is_trade  100768  1728
# is_trade   74154  1266
# is_trade   70745  1274
# is_trade   50917  2138
# is_trade    9413   150
# is_trade    6858   226
# is_trade    2167    79
# is_trade    1916    50
# is_trade    1788   118
# is_trade    1177    30
# is_trade     179     7
# is_trade     118     5
# is_trade      87     1

# %%
dftrain["is_trade"].value_counts()
# Out:
# 0    469117
# 1      9021
# Name: is_trade, dtype: int64

# %%
9021/(469117 + 9021) *100
# Out:
# 1.886693799697995
