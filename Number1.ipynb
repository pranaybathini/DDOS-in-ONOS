# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("round1_ijcai_18_train_20180301.csv", sep= ' ')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478138 entries, 0 to 478137
# Data columns (total 27 columns):
# instance_id                  478138 non-null int64
# item_id                      478138 non-null int64
# item_category_list           478138 non-null object
# item_property_list           478138 non-null object
# item_brand_id                478138 non-null int64
# item_city_id                 478138 non-null int64
# item_price_level             478138 non-null int64
# item_sales_level             478138 non-null int64
# item_collected_level         478138 non-null int64
# item_pv_level                478138 non-null int64
# user_id                      478138 non-null int64
# user_gender_id               478138 non-null int64
# user_age_level               478138 non-null int64
# user_occupation_id           478138 non-null int64
# user_star_level              478138 non-null int64
# context_id                   478138 non-null int64
# ...

# %%
listt = ["item_category_list","item_property_list","predict_category_property","is_trade"]
y = df.is_trade
x = df.drop(listt, axis = 1)
x.head()
# Out:
#            instance_id              item_id        item_brand_id  \
# 0   108641074714126964  3412720377098676069  1975590437749032870
# 1  5754713551599725161  3412720377098676069  1975590437749032870
# 2   842679481291040981  3412720377098676069  1975590437749032870
# 3   937088850059189027  3412720377098676069  1975590437749032870
# 4  7975697065017708072  3412720377098676069  1975590437749032870
#
#           item_city_id  item_price_level  item_sales_level  \
# 0  3948283326616421003                 3                 3
# 1  3948283326616421003                 3                 3
# 2  3948283326616421003                 3                 3
# 3  3948283326616421003                 3                 3
# 4  3948283326616421003                 3                 3
#
#    item_collected_level  item_pv_level              user_id  user_gender_id  \
# 0                     4             14  4505772604969228686               1
# ...

# %%
y.value_counts()
# Out:
# 0    469117
# 1      9021
# Name: is_trade, dtype: int64

# %%
469117/9021
# Out:
# 52.00277131138455

# %%
f,ax = plt.subplots(figsize=(23, 23))
sns.heatmap(x.corr(), annot=True, linewidths=.5, fmt= '.1f',ax=ax)

# %%
ti = x.context_timestamp

# %%
date = pd.to_datetime(ti)

# %%
date.head()
# Out:
# 0   1970-01-01 00:00:01.537236544
# 1   1970-01-01 00:00:01.537243232
# 2   1970-01-01 00:00:01.537211052
# 3   1970-01-01 00:00:01.537222670
# 4   1970-01-01 00:00:01.537271320
# Name: context_timestamp, dtype: datetime64[ns]

# %%
date = date.dt.date

# %%
date = pd.DataFrame(date)

# %%
date.head()
# Out:
#   context_timestamp
# 0        1970-01-01
# 1        1970-01-01
# 2        1970-01-01
# 3        1970-01-01
# 4        1970-01-01

# %%
help(pd)
# Out:
# Help on package pandas:
#
# NAME
#     pandas
#
# DESCRIPTION
#     pandas - a powerful data analysis and manipulation library for Python
# ...
#
#     **pandas** is a Python package providing fast, flexible, and expressive data
#     structures designed to make working with "relational" or "labeled" data both
#     easy and intuitive. It aims to be the fundamental high-level building block for
#     doing practical, **real world** data analysis in Python. Additionally, it has
#     the broader goal of becoming **the most powerful and flexible open source data
#     analysis / manipulation tool available in any language**. It is already well on
#     its way toward this goal.
#
#     Main Features
#     -------------
#     Here are just a few of the things that pandas does well:
#
#       - Easy handling of missing data in floating point as well as non-floating
#         point data
#       - Size mutability: columns can be inserted and deleted from DataFrame and
# ...

# %%
z = date.context_timestamp

# %%
z.value_counts()
# Out:
# 1970-01-01    478138
# Name: context_timestamp, dtype: int64

# %%
z = df.context_timestamp

# %%
z.value_counts()
# Out:
# 1537704211    12
# 1537625383    11
# 1537535936    11
# 1537356990    10
# 1537494187    10
# 1537246073    10
# 1537712124    10
# 1537624982     9
# 1537278144     9
# 1537700659     9
# 1537449178     9
# 1537276109     9
# 1537277164     9
# 1537418462     9
# 1537362372     9
# 1537711270     9
# 1537618518     9
# 1537519970     9
# 1537452858     9
# 1537364105     9
# 1537279076     9
# 1537796769     9
# 1537539926     9
# 1537627369     9
# 1537513155     9
# 1537582796     8
# 1537271675     8
# 1537452170     8
# 1537268878     8
# 1537714682     8
#               ..
# 1537526283     1
# 1537524234     1
# 1537516038     1
# 1537436159     1
# 1537427963     1
# 1537610320     1
# 1537612369     1
# 1537614422     1
# 1537274508     1
# 1537317537     1
# 1537315488     1
# 1537766044     1
# 1537235609     1
# 1537747607     1
# 1537227413     1
# 1537225364     1
# 1537272463     1
# 1537276557     1
# 1537268361     1
# 1537773217     1
# 1537247875     1
# ...

# %%
df.context_page_id.value_counts()
# Out:
# 4001    267486
# 4002     43751
# 4003     31455
# 4004     24088
# 4005     18821
# 4006     15096
# 4007     12355
# 4008     10396
# 4009      9014
# 4010      7472
# 4011      6372
# 4012      5801
# 4013      4892
# 4014      4233
# 4015      3823
# 4016      3367
# 4017      2999
# 4018      2535
# 4019      2242
# 4020      1940
# Name: context_page_id, dtype: int64

# %%
cat = df.predict_category_property
cat[0]
# Out:
# '5799347067982556520:-1;509660095530134768:-1;5755694407684602296:-1;8277336076276184272:9148482949976129397;7908382889764677758:-1'

# %%
df.head()
# Out:
#            instance_id              item_id  \
# 0   108641074714126964  3412720377098676069
# 1  5754713551599725161  3412720377098676069
# 2   842679481291040981  3412720377098676069
# 3   937088850059189027  3412720377098676069
# 4  7975697065017708072  3412720377098676069
#
#                         item_category_list  \
# 0  7908382889764677758;5799347067982556520
# 1  7908382889764677758;5799347067982556520
# 2  7908382889764677758;5799347067982556520
# 3  7908382889764677758;5799347067982556520
# 4  7908382889764677758;5799347067982556520
#
#                                   item_property_list        item_brand_id  \
# 0  2072967855524022579;5131280576272319091;263639...  1975590437749032870
# 1  2072967855524022579;5131280576272319091;263639...  1975590437749032870
# 2  2072967855524022579;5131280576272319091;263639...  1975590437749032870
# 3  2072967855524022579;5131280576272319091;263639...  1975590437749032870
# ...

# %%
f,ax = plt.subplots(figsize=(23, 23))
sns.heatmap(df.corr(), annot=True, linewidths=.5, fmt= '.1f',ax=ax)

# %%
df.item_city_id.value_counts()
# Out:
# 7534238860363577544    154991
# 7322157373578955368     58326
# 3948283326616421003     54472
# 5918626470536001929     34952
# 196257267849351217      30276
# 3122721854741763495     24762
# 1019055478500227370     19701
# 4644954126004286009     18749
# 4918413420989329604     10683
# 6738283504825746594      6877
# 2171543029187596030      5916
# 8240548652619864253      4257
# 3819392654129628501      3921
# 4899814843172066235      3734
# 6652984710464900997      3348
# 9088192369782437159      2938
# 2577951605337750872      2435
# 1548565541085191105      2213
# 2174699138227015967      2186
# 8519578687848277273      2031
# 5326000431362991708      1784
# 8762827044490678569      1778
# 548352491538518780       1770
# 8480550192700287318      1649
# 5161571070109172606      1548
# 8072963182326625214      1385
# 1659868702501373320      1228
# 8774880668563049760      1110
# 739849083029856578       1076
# 3508092439405455063      1063
#                         ...
# ...

# %%
category = df.item_category_list

# %%
type(category)
category = category.str.split(';')

# %%
type(category)
category.size
category.shape
category
# Out:
# 0         [7908382889764677758, 5799347067982556520]
# 1         [7908382889764677758, 5799347067982556520]
# 2         [7908382889764677758, 5799347067982556520]
# 3         [7908382889764677758, 5799347067982556520]
# 4         [7908382889764677758, 5799347067982556520]
# 5         [7908382889764677758, 5799347067982556520]
# 6         [7908382889764677758, 8277336076276184272]
# 7         [7908382889764677758, 8277336076276184272]
# 8         [7908382889764677758, 5755694407684602296]
# 9         [7908382889764677758, 8277336076276184272]
# 10        [7908382889764677758, 8277336076276184272]
# 11        [7908382889764677758, 5755694407684602296]
# 12        [7908382889764677758, 8277336076276184272]
# 13        [7908382889764677758, 8277336076276184272]
# 14        [7908382889764677758, 8277336076276184272]
# 15        [7908382889764677758, 8277336076276184272]
# 16        [7908382889764677758, 5755694407684602296]
# 17        [7908382889764677758, 5755694407684602296]
# ...

# %%
category = pd.DataFrame(category)
category.head()
y = category.iloc[0]
lis = y[0]
lis[0]
# Out:
# '7908382889764677758'

# %%
lit = []
for i in range(478138):
    y = category.iloc[i]
    lis = y[0]
    lit.append(lis[1])

# %%
category = pd.Series(lit)

# %%
category.size
# Out:
# 478138

# %%
df["item_category_list"] = category
df.head()
# Out:
#            instance_id              item_id   item_category_list  \
# 0   108641074714126964  3412720377098676069  5799347067982556520
# 1  5754713551599725161  3412720377098676069  5799347067982556520
# 2   842679481291040981  3412720377098676069  5799347067982556520
# 3   937088850059189027  3412720377098676069  5799347067982556520
# 4  7975697065017708072  3412720377098676069  5799347067982556520
#
#                                   item_property_list        item_brand_id  \
# 0  2072967855524022579;5131280576272319091;263639...  1975590437749032870
# 1  2072967855524022579;5131280576272319091;263639...  1975590437749032870
# 2  2072967855524022579;5131280576272319091;263639...  1975590437749032870
# 3  2072967855524022579;5131280576272319091;263639...  1975590437749032870
# 4  2072967855524022579;5131280576272319091;263639...  1975590437749032870
#
#           item_city_id  item_price_level  item_sales_level  \
# 0  3948283326616421003                 3                 3
# ...

# %%
category = df.item_property_list
df.head()
category = category.str.split(";")

# %%
y = category[0]
len(y)
# Out:
# 22

# %%
type(category)
# Out:
# pandas.core.series.Series

# %%
dicti = {}
leni = 0 
for i in range(478138):
    a = len(category[i])
    dicti[a] = i
    leni = leni + a

# %%
len(dicti)
leni
# Out:
# 16484657

# %%
dicti.keys()
# Out:
# dict_keys([22, 50, 46, 30, 32, 35, 33, 48, 29, 39, 25, 37, 24, 34, 27, 59, 26, 43, 20, 21, 28, 17, 41, 13, 19, 38, 23, 45, 36, 49, 51, 31, 44, 16, 18, 40, 15, 14, 64, 55, 42, 47, 57, 10, 12, 100, 54, 76, 52, 63, 6, 53, 60, 71, 62, 58, 67, 56, 61, 68, 11, 88, 97, 73, 75, 85, 82, 89, 9, 70, 8, 93, 66, 91, 7, 72, 65, 74, 99])

# %%
fra = pd.DataFrame(category)

# %%
fra.to_csv("properties.csv")

# %%
y = category[0]
type(y[0])
# Out:
# str

# %%
prop = {}
for i in range(478138):
    y = category[i]
    for s in y:
        prop[s] = 1

# %%
len(prop)
# Out:
# 61407

# %%
li = prop.keys()
outfile = open('prop.txt', 'w')
for i in li:
    outfile.write(str(i) + " ")

# %%
y = df.item_category_list
type(y)
# Out:
# pandas.core.series.Series

# %%
cat = {}
for i in y:
    cat[i] = 1

# %%
len(cat)
# Out:
# 13

# %%
y.value_counts()
# Out:
# 8277336076276184272    150779
# 5755694407684602296    102496
# 509660095530134768      75420
# 5799347067982556520     72019
# 7258015885215914736     53055
# 2011981573061447208      9563
# 8710739180200009128      7084
# 3203673979138763595      2246
# 2642175453151805566      2029
# 2436715285093487584      1966
# 4879721024980945592      1207
# 1968056100269760729       186
# 22731265849056483          88
# Name: item_category_list, dtype: int64

# %%
outfile = open('cat.txt', 'w')
ini = cat.keys()
for i in ini:
    outfile.write(str(i) + " ")

# %%
df.to_csv("data.csv", encoding='utf-8', index=False)
